# %%
l=[1,2,3,4]
sum_of_list=sum(l)
count=len(l)
print("sum", sum_of_list) 
print("count", count)
# Out:
# sum 10
# count 4

# %%
M=[14,42,17,19]
sum_of_M=sum(M)
count_of_M=len(M)
print("sum_of_M =", sum_of_M)
print("count_of_M =", count_of_M)
# Out:
# sum_of_M = 92
# count_of_M = 4

# %%
M=[14,42,17,19,67,90,45,23]
sum_of_M=sum(M)
count_of_M=len(M)
mean=sum_of_M/count_of_M
print("sum_of_M =", sum_of_M)
print("count_of_M =", count_of_M)
print("mean=", mean)
# Out:
# sum_of_M = 317
# count_of_M = 8
# mean= 39.625

# %%
Q=[24,19,18,17,34,71]
sum_of_Q=sum(Q)
count_of_Q=len(Q)
mean=sum_of_Q/count_of_Q
print("sum_of_Q =", sum_of_Q)
print("count_of_Q =", count_of_Q)
print("mean=", mean)
# Out:
# sum_of_Q = 183
# count_of_Q = 6
# mean= 30.5

# %%
S=[3,6,4,8]
sum=sum(S)
print("Sum=",sum)
# Out:
# Sum= 21

# %%
S=[3,6,4,8]
count=len(S)
print("COUNT=",count)
# Out:
# COUNT= 4

# %%
S=[3,6,4,8]
sum=sum(S)
count=len(S)
mean=sum/count
print("Sum=",sum)
print("COUNT=",count)
print("mean=", mean)
# Out:
# Sum= 21
# COUNT= 4
# mean= 5.25

# %%
F=[13,63,42,81]
sum=sum(F)
count=len(F)
mean=sum/count
print("SUM=",sum)
print("COUNT=",count)
print("MEAN=", mean)
# Out:
# SUM= 199
# COUNT= 4
# MEAN= 49.75
